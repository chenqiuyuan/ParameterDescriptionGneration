# %%
import pandas as pd
import json
import os

DATA_DIR = "/data/ncc_data"
# download data and extract it in raw dir
CODE_SEARCH_NET_FENG_DIR = os.path.join(DATA_DIR, "code_search_net_feng", "raw") 

# LANGUAGE = ["go", "java", "javascript", "php", "python", "ruby"]
# We use Java language
LANGUAGE = ["java"]

DATA_SPLIT = ["valid", "test", "train"]

def temp_format(x):
    return "{:,}".format(x)

def add_table_star(table_path: str):
    with open(table_path, "r") as f:
        file_data = f.read()

    file_data = file_data.replace("\\begin{table}", "\\begin{table*}")
    file_data = file_data.replace("\\end{table}", "\\end{table*}")

    with open(table_path, "w") as f:
        f.write(file_data)

def change_table_font(table_path: str):
    with open(table_path, "r") as f:
        file_data = f.read()

    file_data = file_data.replace("\\centering", "\\centering\n\\small")

    with open(table_path, "w") as f:
        f.write(file_data)

def count_data(language_list, split_list):
    table = []
    
    for lang in language_list:
        for split in split_list:
            data_len = pd.DataFrame()
            data_file = os.path.join(CODE_SEARCH_NET_FENG_DIR, lang, f"{split}.jsonl")
            with open(data_file) as f:
                data = pd.read_json(f, lines=True)

                data_len["Code Length"] = data["code_tokens"].apply(len)
                data_len["Doc Length"] = data["docstring_tokens"].apply(len)
                description = data_len.describe()
                description = description.T
                description["split"] = split
                description.index.name = 'type'
                description = description.reset_index()
                table.append(description)
    final_table = pd.concat(table)

    
    return final_table


if __name__ == "__main__":
    """
    python -m data.draw_table
    """
    # data = count_data()
    table = count_data(LANGUAGE, DATA_SPLIT)
    display(table)

    table[["count", "min", "25%", "50%", "75%", "max"]] = table[["count", "min", "25%", "50%", "75%", "max"]].astype("int64")

    table["count"] = table["count"].map(lambda x: format(x, ","))
    multi_index = pd.MultiIndex.from_frame(table[["split", "count", "type"]], names=["Data Split", "Count", "Type"])
    table.drop(["split", "count", "type"], axis=1, inplace=True)
    table.index = multi_index

    columns = ["Mean", "Std.", "Minimum", "1st Qua.", "Median", "3rd Qua.", "Maximum"]
    table.columns = columns
    display(table)
# Out:
#           type     count       mean        std   min   25%   50%    75%  \
# 0  Code Length    5183.0  88.684353  74.809153  18.0  40.0  61.0  108.0
# 1   Doc Length    5183.0  13.390122  10.158273   3.0   7.0  11.0   16.0
# 0  Code Length   10955.0  97.811684  80.573228  20.0  45.0  69.0  120.0
# 1   Doc Length   10955.0  12.706162   9.588451   3.0   7.0  10.0   15.0
# 0  Code Length  164923.0  98.681524  82.897470  17.0  44.0  69.0  121.0
# 1   Doc Length  164923.0  13.251778  10.028045   3.0   7.0  10.0   16.0
#
#      max  split
# 0  500.0  valid
# 1  147.0  valid
# 0  511.0   test
# 1  111.0   test
# 0  512.0  train
# 1  173.0  train
#                                      Mean       Std.  Minimum  1st Qua.  \
# Data Split Count   Type
# valid      5,183   Code Length  88.684353  74.809153       18        40
#                    Doc Length   13.390122  10.158273        3         7
# test       10,955  Code Length  97.811684  80.573228       20        45
#                    Doc Length   12.706162   9.588451        3         7
# train      164,923 Code Length  98.681524  82.897470       17        44
#                    Doc Length   13.251778  10.028045        3         7
#
#                                 Median  3rd Qua.  Maximum
# Data Split Count   Type
# valid      5,183   Code Length      61       108      500
#                    Doc Length       11        16      147
# test       10,955  Code Length      69       120      511
#                    Doc Length       10        15      111
# train      164,923 Code Length      69       121      512
#                    Doc Length       10        16      173

# %%
latex = table.to_latex(
    float_format="%.2f",
    label="tab:count_data",
    caption="Data count and statistics (the minimum, the first quarter (25\%), and median (50\%), the third quarter (75\%), and the maximum number) of code tokens and documentation words for each data split.",
)

table_dir = "/mnt/c/Users/38013/OneDrive/Paper/LatexParameterDescriptionGeneration/tables"
table_path = os.path.join(table_dir, "table_count_data.tex")

with open(table_path, "w") as f:
    f.write(latex)

add_table_star(table_path)
print(latex)
print(table_path)
# Out:
# \begin{table}
# \centering
# \caption{Data count and statistics of code tokens and documentation tokens for each data split.}
# \label{tab:count_data}
# \begin{tabular}{lllrrrrrrr}
# \toprule
#       &         &            &  Mean &  Std. &  Minimum &  1st Qua. &  Median &  3rd Qua. &  Maximum \\
# Data Split & Count & Type &       &       &          &           &         &           &          \\
# \midrule
# valid & 5,183 & Code Length & 88.68 & 74.81 &       18 &        40 &      61 &       108 &      500 \\
#       &         & Doc Length & 13.39 & 10.16 &        3 &         7 &      11 &        16 &      147 \\
# test & 10,955 & Code Length & 97.81 & 80.57 &       20 &        45 &      69 &       120 &      511 \\
#       &         & Doc Length & 12.71 &  9.59 &        3 &         7 &      10 &        15 &      111 \\
# train & 164,923 & Code Length & 98.68 & 82.90 &       17 &        44 &      69 &       121 &      512 \\
#       &         & Doc Length & 13.25 & 10.03 &        3 &         7 &      10 &        16 &      173 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# /mnt/c/Users/38013/OneDrive/Paper/LatexParameterDescriptionGeneration/tables/table_count_data.tex
# /tmp/ipykernel_278/1530517164.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex = table.to_latex(

# %%
from IPython.display import display
# Valid Data
data_file = os.path.join(CODE_SEARCH_NET_FENG_DIR, f"java/test.jsonl")
with open(data_file) as f:
    valid_data = pd.read_json(f, lines=True)
display(valid_data)
# Out:
#                        repo  \
# 0          ReactiveX/RxJava
# 1          ReactiveX/RxJava
# 2          ReactiveX/RxJava
# 3          ReactiveX/RxJava
# 4          ReactiveX/RxJava
# ...                     ...
# 10950  ieb/sparsemapcontent
# 10951   intellimate/IzouSDK
# 10952   intellimate/IzouSDK
# 10953        abmargb/jamppa
# 10954        abmargb/jamppa
#
#                                                     path  \
# 0      src/main/java/io/reactivex/internal/observers/...
# 1             src/main/java/io/reactivex/Observable.java
# 2             src/main/java/io/reactivex/Observable.java
# 3      src/main/java/io/reactivex/internal/operators/...
# 4      src/main/java/io/reactivex/processors/UnicastP...
# ...                                                  ...
# 10950  core/src/main/java/org/sakaiproject/nakamura/l...
# 10951  src/main/java/org/intellimate/izou/sdk/addon/A...
# 10952  src/main/java/org/intellimate/izou/sdk/addon/A...
# 10953  src/main/java/org/jivesoftware/smack/Reconnect...
# 10954  src/main/java/org/jivesoftware/smack/Reconnect...
#
#                                             func_name  \
# 0              QueueDrainObserver.fastPathOrderedEmit
# 1                                     Observable.wrap
# 2                                   Observable.sorted
# 3                          ObservableReplay.observeOn
# 4                             UnicastProcessor.create
# ...                                               ...
# 10950                            Types.loadFromStream
# 10951                                  AddOn.register
# 10952                                 AddOn.initAddOn
# 10953    ReconnectionManager.notifyReconnectionFailed
# 10954  ReconnectionManager.notifyAttemptToReconnectIn
#
#                                          original_string language  \
# 0      protected final void fastPathOrderedEmit(U val...     java
# 1      @CheckReturnValue\n    @SchedulerSupport(Sched...     java
# 2      @CheckReturnValue\n    @SchedulerSupport(Sched...     java
# 3      public static <T> ConnectableObservable<T> obs...     java
# 4      @CheckReturnValue\n    @NonNull\n    public st...     java
# ...                                                  ...      ...
# 10950  public static void loadFromStream(String key, ...     java
# 10951  @Override\n    public void register() {\n     ...     java
# 10952  @Override\n    public void initAddOn(org.intel...     java
# 10953  protected void notifyReconnectionFailed(Except...     java
# 10954  protected void notifyAttemptToReconnectIn(int ...     java
#
#                                                     code  \
# 0      protected final void fastPathOrderedEmit(U val...
# 1      @CheckReturnValue\n    @SchedulerSupport(Sched...
# 2      @CheckReturnValue\n    @SchedulerSupport(Sched...
# 3      public static <T> ConnectableObservable<T> obs...
# 4      @CheckReturnValue\n    @NonNull\n    public st...
# ...                                                  ...
# 10950  public static void loadFromStream(String key, ...
# 10951  @Override\n    public void register() {\n     ...
# 10952  @Override\n    public void initAddOn(org.intel...
# 10953  protected void notifyReconnectionFailed(Except...
# 10954  protected void notifyAttemptToReconnectIn(int ...
#
#                                              code_tokens  \
# 0      [protected, final, void, fastPathOrderedEmit, ...
# 1      [@, SchedulerSupport, (, SchedulerSupport, ., ...
# 2      [@, SchedulerSupport, (, SchedulerSupport, ., ...
# 3      [public, static, <, T, >, ConnectableObservabl...
# 4      [public, static, <, T, >, UnicastProcessor, <,...
# ...                                                  ...
# 10950  [public, static, void, loadFromStream, (, Stri...
# 10951  [public, void, register, (, ), {, prepare, (, ...
# 10952  [public, void, initAddOn, (, org, ., intellima...
# 10953  [protected, void, notifyReconnectionFailed, (,...
# 10954  [protected, void, notifyAttemptToReconnectIn, ...
#
#                                                docstring  \
# 0      Makes sure the fast-path emits in order.\n@par...
# 1      Wraps an ObservableSource into an Observable i...
# 2      Returns an Observable that emits the events em...
# 3      Child Observers will observe the events of the...
# 4      Creates an UnicastProcessor with the given int...
# ...                                                  ...
# 10950  Load a Map from binary stream\n\n@param output...
# 10951        This method is used to register the modules
# 10952  Internal initiation of addOn - fake constructo...
# 10953  Fires listeners when a reconnection attempt ha...
# 10954  Fires listeners when The Connection will retry...
#
#                                         docstring_tokens  \
# 0      [Makes, sure, the, fast, -, path, emits, in, o...
# 1      [Wraps, an, ObservableSource, into, an, Observ...
# 2      [Returns, an, Observable, that, emits, the, ev...
# 3      [Child, Observers, will, observe, the, events,...
# 4      [Creates, an, UnicastProcessor, with, the, giv...
# ...                                                  ...
# 10950               [Load, a, Map, from, binary, stream]
# 10951  [This, method, is, used, to, register, the, mo...
# 10952  [Internal, initiation, of, addOn, -, fake, con...
# 10953  [Fires, listeners, when, a, reconnection, atte...
# 10954  [Fires, listeners, when, The, Connection, will...
#
#                                             sha  \
# 0      ac84182aa2bd866b53e01c8e3fe99683b882c60e
# 1      ac84182aa2bd866b53e01c8e3fe99683b882c60e
# 2      ac84182aa2bd866b53e01c8e3fe99683b882c60e
# 3      ac84182aa2bd866b53e01c8e3fe99683b882c60e
# 4      ac84182aa2bd866b53e01c8e3fe99683b882c60e
# ...                                         ...
# 10950  0570fdf868adbbf7734790cbc09fe66480e5f2dc
# 10951  bc8705ad48a6ca12a722f2b787be435949fa5d08
# 10952  bc8705ad48a6ca12a722f2b787be435949fa5d08
# 10953  76f253239923df40904c462e3b88e7278b36b282
# 10954  76f253239923df40904c462e3b88e7278b36b282
#
#                                                      url partition
# 0      https://github.com/ReactiveX/RxJava/blob/ac841...      test
# 1      https://github.com/ReactiveX/RxJava/blob/ac841...      test
# 2      https://github.com/ReactiveX/RxJava/blob/ac841...      test
# 3      https://github.com/ReactiveX/RxJava/blob/ac841...      test
# 4      https://github.com/ReactiveX/RxJava/blob/ac841...      test
# ...                                                  ...       ...
# 10950  https://github.com/ieb/sparsemapcontent/blob/0...      test
# 10951  https://github.com/intellimate/IzouSDK/blob/bc...      test
# 10952  https://github.com/intellimate/IzouSDK/blob/bc...      test
# 10953  https://github.com/abmargb/jamppa/blob/76f2532...      test
# 10954  https://github.com/abmargb/jamppa/blob/76f2532...      test
#
# [10955 rows x 12 columns]

# %%
data = valid_data
data["code_len"] = data["code_tokens"].apply(len)
data["doc_len"] = data["docstring_tokens"].apply(len)
count_code_len = data["code_len"].describe()
count_doc_len = data["doc_len"].describe()
df = data.describe()
display(df)
# Out:
#           code_len      doc_len
# count  5183.000000  5183.000000
# mean     88.684353    13.390122
# std      74.809153    10.158273
# min      18.000000     3.000000
# 25%      40.000000     7.000000
# 50%      61.000000    11.000000
# 75%     108.000000    16.000000
# max     500.000000   147.000000

# %%
table = df.copy()
table.columns = pd.MultiIndex.from_product([["Valid"], df.columns])

# display(table.T)
pd.concat([table, table], axis=1)
# Out:
#              Valid
#           code_len      doc_len     code_len      doc_len
# count  5183.000000  5183.000000  5183.000000  5183.000000
# mean     88.684353    13.390122    88.684353    13.390122
# std      74.809153    10.158273    74.809153    10.158273
# min      18.000000     3.000000    18.000000     3.000000
# 25%      40.000000     7.000000    40.000000     7.000000
# 50%      61.000000    11.000000    61.000000    11.000000
# 75%     108.000000    16.000000   108.000000    16.000000
# max     500.000000   147.000000   500.000000   147.000000
